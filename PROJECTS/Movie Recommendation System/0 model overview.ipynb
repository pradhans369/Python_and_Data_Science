# %% [markdown]
# Types of recommendation systems:
# 1. Content based
#     - based on the content
# 2. Collaborative filtering based
#     - based on user behaviour (like recommending something what user consumes)
# 3. Hybrid based
#     - mix of both content and collaborative filtering
#
#
# Now we are going to work on content recommendation systems.

# %% [markdown]
# Bird eye view of the recommendation system
# - Data gathering
# - Preprocessing
# - Model building
# - Website making
# - Deploying the website
