# %%
# %load_ext cudf.pandas
import pandas as pd
import numpy as np
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import Sequential, layers, regularizers                       # regularizers -- adding regularization into the model (L1, and L2)
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.datasets import mnist
# Out:
# The cudf.pandas extension is already loaded. To reload it, use:
#   %reload_ext cudf.pandas

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape)
print(x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# (60000, 28, 28)
# (10000, 28, 28)

# %%
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# %%
print(x_train.shape)
# Out:
# (60000, 28, 28)

# %%
model = keras.Sequential([
    keras.Input(shape=(None, 28)),
    layers.SimpleRNN(512, return_sequences=True, activation='relu'),
    layers.SimpleRNN(512, activation='relu'),
    layers.Dense(10)
])


model.compile(
    loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer = keras.optimizers.Adam(0.001),
    metrics = ['accuracy']
)

model.fit(
    x_train, y_train,
    batch_size=64,
    epochs=10,
    verbose = True
)

model.evaluate(
    x_test, y_test,
    batch_size = 64,
    verbose = 2
)
# Out:
# Epoch 1/10
#  11/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.1531 - loss: 2.1939
# I0000 00:00:1789963547.761971     211 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - accuracy: 0.9018 - loss: 0.3167
# Epoch 2/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9614 - loss: 0.1433
# Epoch 3/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9654 - loss: 0.1284
# Epoch 4/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9710 - loss: 0.1039
# Epoch 5/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9739 - loss: 0.0962
# Epoch 6/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9759 - loss: 0.0897
# Epoch 7/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9754 - loss: 0.0904
# Epoch 8/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9795 - loss: 0.0737
# Epoch 9/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9819 - loss: 0.0671
# Epoch 10/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9823 - loss: 0.0663
# 157/157 - 2s - 11ms/step - accuracy: 0.9791 - loss: 0.0750
# [0.07495389133691788, 0.9790999889373779]
