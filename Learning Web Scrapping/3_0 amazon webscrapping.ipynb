# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

options = Options()
options.add_experimental_option("detach", True) 

# -----------------------------------------------
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)

options.add_argument("--disable-blink-features=AutomationControlled")

options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36")
# -----------------------------------------------


brave_path = r"C:\Users\biswa\AppData\Local\BraveSoftware\Brave-Browser\Application\brave.exe"
options.binary_location = brave_path


driver = webdriver.Chrome(options=options)

search = "mobiles"
# pageNo = "2"

lists = []

for i in range(0, 3):
    driver.get(f"https://www.amazon.in/s?k={search}&page={i}&xpid=7X1j0yjYU1Dx7&crid=248K4SV2XN0VI&qid=1774618904&sprefix=phone%2Caps%2C408&ref=sr_pg_2")       # here we created the for loop to iterate through all pages

    # https://www.amazon.in/s?k={search}&page={i}&xpid=7X1j0yjYU1Dx7&crid=248K4SV2XN0VI&qid=1774618904&sprefix=phone%2Caps%2C408&ref=sr_pg_2
    elements = driver.find_elements(By.CLASS_NAME, "puis-card-container")

    for i in elements:
        lists.append(i)
        print(i.text)



    # print(element.get_attribute("outerHTML"))       # will give entire html of the mentioned class

    # innerHTML gives you everything inside the element (but excludes the element itself). outerHTML gives you everything inside the element, plus the element itself.


driver.close()
# Out:
# Sponsored
# Samsung Galaxy S26 5G (Sky Blue, 12GB RAM, 512GB Storage), AI Phone, Photo Assist, Creative Studio, 50MP Camera with ProVisual Engine, Powerful Customized Processor and 4300mAh Battery
# ₹1,07,999
# Flat INR 4000 Off on HDFC BankCar...
# FREE delivery Sun, 29 Mar
# Add to cart
# +3 other colors/patterns
# Sponsored
# Samsung Galaxy S26 Ultra 5G (White, 12GB RAM, 512GB Storage) with Built-in Privacy Display, AI Phone, Photo Assist, Creative Studio, 200MP Camera, 5000mAh Battery and Snapdragon 8 Elite Gen 5
# 5.0
# (1)
# ₹1,59,999
# Save extra with No Cost EMI
# FREE delivery Sun, 29 Mar
# Add to cart
# +3 other colors/patterns
# iQOO Neo 10R 5G (Raging Blue, 12GB RAM, 256GB Storage) | Snapdragon 8s Gen 3 Processor | India's Slimmest 6400mAh Battery Smartphone | Segment's Most Stable 90FPS for 5 Hours
# 4.4
# (6.6K)
# 1K+ bought in past month
# See options
# Amazon's Choice
# OnePlus Nord CE5 | MediaTek Dimensity | Massive 7100mAh Battery | Powered by OnePlus AI | 8GB + 128GB | Nexus Blue
# 4.4
# (5.1K)
# 3K+ bought in past month
# ₹24,996
# M.R.P:
# ₹28,999 (14% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Sun, 29 Mar
# Add to cart
# iQOO Z11x 5G (Titan Black, 6GB RAM, 128 GB Storage) | Dimensity 7400-Turbo Processor | 7200 mAh Battery Smartphone | Powered by OriginOS 6
# ₹18,998
# M.R.P:
# ₹28,999 (34% off)
# 10% Off on select cards
# FREE delivery Sun, 29 Mar
# Add to cart
# Best seller
# iQOO Neo 10 (Titanium Chrome, 16GB RAM, 512GB Storage) | Snapdragon 8s Gen 4 Processor & SuperComputing Chip Q1 | 7000 mAh Battery | Segment’s Highest 144 FPS Gaming Smartphone
# 4.4
# (4.5K)
# 200+ bought in past month
# ₹43,998
# M.R.P:
# ₹45,999 (4% off)
# Save extra with No Cost EMI
# FREE delivery 29 Mar - 4 Apr
# Only 2 left in stock.
# Add to cart
# realme NARZO 90x 5G (Maroon Red,4GB+128GB) | 7000mAh + 60W Biggest Battery & Fastest Charging in The Segment* | 144Hz Bright Display | Sony 50MP AI Rear Camera | AI Assist | 400% Ultra Boom Speaker
# 4.2
# (661)
# 1K+ bought in past month
# ₹12,999
# M.R.P:
# ₹15,999 (19% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Wed, 1 Apr
# Add to cart
# OnePlus 15R | 12GB+256GB | Mint Breeze | World's First Snapdragon® 8 Gen 5 | 7400mAh Battery | Personalised AI | Game-Changing 165Hz Display | IP66 IP68 IP69 & IP69K | 4K 120fps Video
# 4.5
# (875)
# 1K+ bought in past month
# ₹47,997
# M.R.P:
# ₹54,999 (13% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Sun, 29 Mar
# Add to cart
# realme NARZO 80 Pro 5G (Speed Silver,12GB+256GB) | Segment's 1st MediaTek Dimensity 7400 Chipset | 6000mAh Titan Battery + 80W Ultra Charge | 4500nits HyperGlow Esports Display | IP69 Waterproof
# 4.3
# (2.2K)
# 500+ bought in past month
# ₹21,999
# M.R.P:
# ₹27,999 (21% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Sun, 29 Mar
# Add to cart
# iQOO Z11x 5G (Prismatic Green, 6GB RAM, 128 GB Storage) | Dimensity 7400-Turbo Processor | 7200 mAh Battery Smartphone | Powered by OriginOS 6
# ₹18,998
# M.R.P:
# ₹28,999 (34% off)
# 10% Off on select cards
# FREE delivery Sun, 29 Mar
# Add to cart
# Sponsored
# Samsung Galaxy S26 Plus 5G (Black, 12GB RAM, 256GB Storage), AI Phone, Photo Assist, Creative Studio, 50MP Camera, 4900mAh Battery and Super Fast Wireless Charging
# ₹1,19,999
# Flat INR 5000 Off on HDFC BankCar...
# FREE delivery Sun, 29 Mar
# Add to cart
# +1 other color/pattern
# Sponsored
# iPhone Air 512 GB: Thinnest iPhone Ever, 16.63 cm (6.5″) Display with Promotion up to 120Hz, Powerful A19 Pro Chip, Center Stage Front Camera, All-Day Battery Life; Cloud White
# 5.0
# (2)
# ₹1,13,990
# M.R.P:
# ₹1,39,900 (19% off)
# Save ₹5,000 with coupon
# FREE delivery Sun, 29 Mar
# Add to cart
# Samsung Galaxy M56 5G Mobile (Black, 8GB RAM, 256GB Storage)| Segment's Slimmest | Gorilla Glass Victus+| 10 Bit HDR Video| 50MP Camera| AI | Vapour Cooling Chamber| Lag-Free Gaming| Without Charger
# 4.3
# (1K)
# 1K+ bought in past month
# ₹25,999
# M.R.P:
# ₹33,999 (24% off)
# Save extra with No Cost EMI
# FREE delivery Sun, 29 Mar
# Add to cart
# +3 other colors/patterns
# Samsung Galaxy S26 Ultra 5G (White, 12GB RAM, 512GB Storage) with Built-in Privacy Display, AI Phone, Photo Assist, Creative Studio, 200MP Camera, 5000mAh Battery and Snapdragon 8 Elite Gen 5
# 5.0
# (1)
# ₹1,59,999
# Save extra with No Cost EMI
# FREE delivery Sun, 29 Mar
# Add to cart
# iPhone Air 512 GB: Thinnest iPhone Ever, 16.63 cm (6.5″) Display with Promotion up to 120Hz, Powerful A19 Pro Chip, Center Stage Front Camera, All-Day Battery Life; Cloud White
# 5.0
# (2)
# ₹1,13,990
# M.R.P:
# ₹1,39,900 (19% off)
# Save ₹5,000 with coupon
# FREE delivery Sun, 29 Mar
# Add to cart
# +2 other colors/patterns
# OnePlus 15R | 12GB+256GB | Mint Breeze | World's First Snapdragon® 8 Gen 5 | 7400mAh Battery | Personalised AI | Game-Changing 165Hz Display | IP66 IP68 IP69 & IP69K | 4K 120fps Video
# 4.5
# (875)
# 1K+ bought in past month
# ₹47,997
# M.R.P:
# ₹54,999 (13% off)
# Up to 5% back with Amazon Pay I...
# FREE delivery Sun, 29 Mar
# Add to cart
#
#
# iQOO Z10 5G (Glacier Silver, 12GB RAM, 256GB Storage) | India's Biggest Ever 7300 mAh Battery | Snapdragon 7s Gen 3 Processor | Brightest Quad Curved AMOLED Display in the Segment
# 4.3
# (4.8K)
# 500+ bought in past month
# ₹28,998
# M.R.P:
# ₹29,999 (3% off)
# Save extra with No Cost EMI
# FREE delivery 29 Mar - 5 Apr
# Only 2 left in stock.
# Add to cart
# Samsung Galaxy M07 Mobile (Black, 4GB RAM, 64GB Storage) | MediaTek Helio G99 | AnTuTu 624K | IP54| 50MP Camera | 7.6mm Slim | 5000mAh Battery | 25W Fast Charging | 6 Gen OS Upgrades | Without Charger
# 4.2
# (940)
# 5K+ bought in past month
# ₹7,999
# M.R.P:
# ₹9,999 (20% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Wed, 1 Apr
# Add to cart
# OPPO K13x 5G 6000mAh and 45W SUPERVOOC Charger & AI (Midnight Violet, 128 GB) (8 GB RAM)
# 4.5
# (74)
# 1K+ bought in past month
# ₹14,899
# M.R.P:
# ₹18,999 (22% off)
# FREE delivery Sun, 29 Mar
# Add to cart
# More Buying Choices
# ₹14,495(14 new offers)
# Samsung Galaxy M17 5G Mobile (Sapphire Black, 8GB RAM, 128GB Storage) | 50MP OIS Triple Camera | Gorilla Glass Victus | IP54 | 6 Gen OS Upgrades | AI | Gemini Live | Lag-Free Gaming | Without Charger
# 4.1
# (1.5K)
# 1K+ bought in past month
# ₹16,999
# M.R.P:
# ₹19,499 (13% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Tue, 31 Mar
# Add to cart
# Samsung Galaxy M06 5G Mobile (Blazing Black, 6GB RAM, 128GB Storage) | MediaTek Dimensity 6300 | AnTuTu 623K+ | 12 5G Bands | 25W Fast Charging | 4 Gen OS Upgrades | 50MP Camera | Without Charger
# 4.0
# (3.2K)
# 2K+ bought in past month
# ₹11,999
# M.R.P:
# ₹15,499 (23% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Tue, 31 Mar
# Add to cart
# Samsung Galaxy M17e 5G Mobile (Vibe Violet, 4GB RAM, 128GB Storage) | Smoothest 120 Hz Refresh Rate| Monster 6000 mAh Battery | IP54 | 6 Gen OS Upgrades | AI | Gemini Live | Without Charger
# ₹13,999
# M.R.P:
# ₹16,999 (18% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Sun, 29 Mar
# Add to cart
# Redmi A4 5G (Sparkle Purple, 4GB RAM, 128GB Storage) | Segment Largest 6.88in 120Hz | 50MP Dual Camera | 18W Fast Charging | Charger in the Box
# 3.9
# (5.3K)
# 2K+ bought in past month
# ₹11,999
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Sun, 29 Mar
# Add to cart
# +1 other color/pattern
# Sponsored
# iPhone 16e 512 GB: Built for Apple Intelligence, A18 Chip, Supersized Battery Life, 48MP Fusion. Camera, 15.40 cm (6.1″) Super Retina XDR Display; Black
# 4.5
# (1.1K)
# ₹89,900
# Save extra with No Cost EMI
# FREE delivery Mon, 30 Mar
# Add to cart
# +1 other color/pattern
# Sponsored
# iPhone 17 Pro Max 2 TB: 17.42 cm (6.9″) Display with Promotion, A19 Pro Chip, Best Battery Life in Any iPhone Ever, Pro Fusion Camera System, Center Stage Front Camera; Silver
# 4.4
# (264)
# ₹2,29,900
# Save extra with No Cost EMI
# FREE delivery Tue, 31 Mar
# Add to cart
# +2 other colors/patterns
# Sponsored
# Samsung Galaxy S26 5G (Sky Blue, 12GB RAM, 512GB Storage), AI Phone, Photo Assist, Creative Studio, 50MP Camera with ProVisual Engine, Powerful Customized Processor and 4300mAh Battery
# ₹1,07,999
# Flat INR 4000 Off on HDFC BankCards
# FREE delivery Sun, 29 Mar
# Add to cart
# +3 other colors/patterns
# Sponsored
# Samsung Galaxy S26 Ultra 5G (White, 12GB RAM, 512GB Storage) with Built-in Privacy Display, AI Phone, Photo Assist, Creative Studio, 200MP Camera, 5000mAh Battery and Snapdragon 8 Elite Gen 5
# 5.0
# (1)
# ₹1,59,999
# Save extra with No Cost EMI
# FREE delivery Sun, 29 Mar
# Add to cart
# +3 other colors/patterns
# iQOO Neo 10R 5G (Raging Blue, 12GB RAM, 256GB Storage) | Snapdragon 8s Gen 3 Processor | India's Slimmest 6400mAh Battery Smartphone | Segment's Most Stable 90FPS for 5 Hours
# 4.4
# (6.6K)
# 1K+ bought in past month
# See options
# Amazon's Choice
# OnePlus Nord CE5 | MediaTek Dimensity | Massive 7100mAh Battery | Powered by OnePlus AI | 8GB + 128GB | Nexus Blue
# 4.4
# (5.1K)
# 3K+ bought in past month
# ₹24,996
# M.R.P:
# ₹28,999 (14% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Sun, 29 Mar
# Add to cart
# iQOO Z11x 5G (Titan Black, 6GB RAM, 128 GB Storage) | Dimensity 7400-Turbo Processor | 7200 mAh Battery Smartphone | Powered by OriginOS 6
# ₹18,998
# M.R.P:
# ₹28,999 (34% off)
# 10% Off on select cards
# FREE delivery Sun, 29 Mar
# Add to cart
# Best seller
# iQOO Neo 10 (Titanium Chrome, 16GB RAM, 512GB Storage) | Snapdragon 8s Gen 4 Processor & SuperComputing Chip Q1 | 7000 mAh Battery | Segment’s Highest 144 FPS Gaming Smartphone
# 4.4
# (4.5K)
# 200+ bought in past month
# ₹43,998
# M.R.P:
# ₹45,999 (4% off)
# Save extra with No Cost EMI
# FREE delivery 29 Mar - 4 Apr
# Only 2 left in stock.
# Add to cart
# realme NARZO 90x 5G (Maroon Red,4GB+128GB) | 7000mAh + 60W Biggest Battery & Fastest Charging in The Segment* | 144Hz Bright Display | Sony 50MP AI Rear Camera | AI Assist | 400% Ultra Boom Speaker
# 4.2
# (661)
# 1K+ bought in past month
# ₹12,999
# M.R.P:
# ₹15,999 (19% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Wed, 1 Apr
# Add to cart
# OnePlus 15R | 12GB+256GB | Mint Breeze | World's First Snapdragon® 8 Gen 5 | 7400mAh Battery | Personalised AI | Game-Changing 165Hz Display | IP66 IP68 IP69 & IP69K | 4K 120fps Video
# 4.5
# (875)
# 1K+ bought in past month
# ₹47,997
# M.R.P:
# ₹54,999 (13% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Sun, 29 Mar
# Add to cart
# realme NARZO 80 Pro 5G (Speed Silver,12GB+256GB) | Segment's 1st MediaTek Dimensity 7400 Chipset | 6000mAh Titan Battery + 80W Ultra Charge | 4500nits HyperGlow Esports Display | IP69 Waterproof
# 4.3
# (2.2K)
# 500+ bought in past month
# ₹21,999
# M.R.P:
# ₹27,999 (21% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Sun, 29 Mar
# Add to cart
# iQOO Z11x 5G (Prismatic Green, 6GB RAM, 128 GB Storage) | Dimensity 7400-Turbo Processor | 7200 mAh Battery Smartphone | Powered by OriginOS 6
# ₹18,998
# M.R.P:
# ₹28,999 (34% off)
# 10% Off on select cards
# FREE delivery Sun, 29 Mar
# Add to cart
# Sponsored
# Samsung Galaxy S26 Plus 5G (Black, 12GB RAM, 256GB Storage), AI Phone, Photo Assist, Creative Studio, 50MP Camera, 4900mAh Battery and Super Fast Wireless Charging
# ₹1,19,999
# Flat INR 5000 Off on HDFC BankCards
# FREE delivery Sun, 29 Mar
# Add to cart
# +1 other color/pattern
# Sponsored
# iPhone Air 512 GB: Thinnest iPhone Ever, 16.63 cm (6.5″) Display with Promotion up to 120Hz, Powerful A19 Pro Chip, Center Stage Front Camera, All-Day Battery Life; Light Gold
# 3.0
# (2)
# ₹1,13,990
# M.R.P:
# ₹1,39,900 (19% off)
# Save extra with No Cost EMI
# FREE delivery Tue, 31 Mar
# Only 1 left in stock.
# Add to cart
# Samsung Galaxy M56 5G Mobile (Black, 8GB RAM, 256GB Storage)| Segment's Slimmest | Gorilla Glass Victus+| 10 Bit HDR Video| 50MP Camera| AI | Vapour Cooling Chamber| Lag-Free Gaming| Without Charger
# 4.3
# (1K)
# 1K+ bought in past month
# ₹25,999
# M.R.P:
# ₹33,999 (24% off)
# Save extra with No Cost EMI
# FREE delivery Sun, 29 Mar
# Add to cart
# +3 other colors/patterns
# Samsung Galaxy S26 Ultra 5G (White, 12GB RAM, 512GB Storage) with Built-in Privacy Display, AI Phone, Photo Assist, Creative Studio, 200MP Camera, 5000mAh Battery and Snapdragon 8 Elite Gen 5
# 5.0
# (1)
# ₹1,59,999
# Save extra with No Cost EMI
# FREE delivery Sun, 29 Mar
# Add to cart
# iPhone Air 512 GB: Thinnest iPhone Ever, 16.63 cm (6.5″) Display with Promotion up to 120Hz, Powerful A19 Pro Chip, Center Stage Front Camera, All-Day Battery Life; Cloud White
# 5.0
# (2)
# ₹1,13,990
# M.R.P:
# ₹1,39,900 (19% off)
# Save ₹5,000 with coupon
# FREE delivery Sun, 29 Mar
# Add to cart
# +2 other colors/patterns
# OnePlus 15R | 12GB+256GB | Mint Breeze | World's First Snapdragon® 8 Gen 5 | 7400mAh Battery | Personalised AI | Game-Changing 165Hz Display | IP66 IP68 IP69 & IP69K | 4K 120fps Video
# 4.5
# (875)
# 1K+ bought in past month
# ₹47,997
# M.R.P:
# ₹54,999 (13% off)
# Up to 5% back with Amazon Pay I...
# FREE delivery Sun, 29 Mar
# Add to cart
#
#
# iQOO Z10 5G (Glacier Silver, 12GB RAM, 256GB Storage) | India's Biggest Ever 7300 mAh Battery | Snapdragon 7s Gen 3 Processor | Brightest Quad Curved AMOLED Display in the Segment
# 4.3
# (4.8K)
# 500+ bought in past month
# ₹28,998
# M.R.P:
# ₹29,999 (3% off)
# Save extra with No Cost EMI
# FREE delivery 29 Mar - 5 Apr
# Only 2 left in stock.
# Add to cart
# Samsung Galaxy M07 Mobile (Black, 4GB RAM, 64GB Storage) | MediaTek Helio G99 | AnTuTu 624K | IP54| 50MP Camera | 7.6mm Slim | 5000mAh Battery | 25W Fast Charging | 6 Gen OS Upgrades | Without Charger
# 4.2
# (940)
# 5K+ bought in past month
# ₹7,999
# M.R.P:
# ₹9,999 (20% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Wed, 1 Apr
# Add to cart
# OPPO K13x 5G 6000mAh and 45W SUPERVOOC Charger & AI (Midnight Violet, 128 GB) (8 GB RAM)
# 4.5
# (74)
# 1K+ bought in past month
# ₹14,899
# M.R.P:
# ₹18,999 (22% off)
# FREE delivery Sun, 29 Mar
# Add to cart
# More Buying Choices
# ₹14,495(14 new offers)
# Samsung Galaxy M17 5G Mobile (Sapphire Black, 8GB RAM, 128GB Storage) | 50MP OIS Triple Camera | Gorilla Glass Victus | IP54 | 6 Gen OS Upgrades | AI | Gemini Live | Lag-Free Gaming | Without Charger
# 4.1
# (1.5K)
# 1K+ bought in past month
# ₹16,999
# M.R.P:
# ₹19,499 (13% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Tue, 31 Mar
# Add to cart
# Samsung Galaxy M06 5G Mobile (Blazing Black, 6GB RAM, 128GB Storage) | MediaTek Dimensity 6300 | AnTuTu 623K+ | 12 5G Bands | 25W Fast Charging | 4 Gen OS Upgrades | 50MP Camera | Without Charger
# 4.0
# (3.2K)
# 2K+ bought in past month
# ₹11,999
# M.R.P:
# ₹15,499 (23% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Tue, 31 Mar
# Add to cart
# Samsung Galaxy M17e 5G Mobile (Vibe Violet, 4GB RAM, 128GB Storage) | Smoothest 120 Hz Refresh Rate| Monster 6000 mAh Battery | IP54 | 6 Gen OS Upgrades | AI | Gemini Live | Without Charger
# ₹13,999
# M.R.P:
# ₹16,999 (18% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Sun, 29 Mar
# Add to cart
# Redmi A4 5G (Sparkle Purple, 4GB RAM, 128GB Storage) | Segment Largest 6.88in 120Hz | 50MP Dual Camera | 18W Fast Charging | Charger in the Box
# 3.9
# (5.3K)
# 2K+ bought in past month
# ₹11,999
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Sun, 29 Mar
# Add to cart
# +1 other color/pattern
# Sponsored
# iPhone 17 Pro 256 GB: 15.93 cm (6.3″) Display with Promotion up to 120Hz, A19 Pro Chip, Breakthrough Battery Life, Pro Fusion Camera System with Center Stage Front Camera; Cosmic Orange
# 4.5
# (347)
# 500+ bought in past month
# ₹1,34,900
# Save extra with No Cost EMI
# FREE delivery Mon, 30 Mar
# Only 2 left in stock.
# Add to cart
# +1 other color/pattern
# Sponsored
# iPhone 17 Pro Max 2 TB: 17.42 cm (6.9″) Display with Promotion, A19 Pro Chip, Best Battery Life in Any iPhone Ever, Pro Fusion Camera System, Center Stage Front Camera; Cosmic Orange
# 4.4
# (264)
# ₹2,29,900
# Save extra with No Cost EMI
# FREE delivery Sun, 29 Mar
# Only 2 left in stock.
# Add to cart
# +2 other colors/patterns
# Sponsored
# Samsung Galaxy S26 5G (Sky Blue, 12GB RAM, 512GB Storage), AI Phone, Photo Assist, Creative Studio, 50MP Camera with ProVisual Engine, Powerful Customized Processor and 4300mAh Battery
# ₹1,07,999
# Flat INR 4000 Off on HDFC BankCards
# FREE delivery Sun, 29 Mar
# Add to cart
# +3 other colors/patterns
# Sponsored
# Samsung Galaxy S26 Ultra 5G (White, 12GB RAM, 512GB Storage) with Built-in Privacy Display, AI Phone, Photo Assist, Creative Studio, 200MP Camera, 5000mAh Battery and Snapdragon 8 Elite Gen 5
# 5.0
# (1)
# ₹1,59,999
# Save extra with No Cost EMI
# FREE delivery Sun, 29 Mar
# Add to cart
# +3 other colors/patterns
# Motorola G57 Power 5G (Corsair, 8GB RAM, 128GB Storage) | Snapdragon 6s Gen 4 Processor | 6.72" FHD+ Display | 50MP LYT-600 + 8MP Ultrawide | 8MP Selfie Camera | 7000mAh Battery, 33W TurboPower | IP64
# 4.2
# (151)
# 5K+ bought in past month
# ₹15,290
# M.R.P:
# ₹17,999 (15% off)
# FREE delivery Sun, 29 Mar
# Add to cart
# More Buying Choices
# ₹14,980(29 new offers)
# Samsung Galaxy M36 5G Mobile (Serene Green, 8GB RAM, 128GB Storage) | Google Gemini| Gorilla Glass Victus+ | 7.7mm | AI Enhanced 50MP OIS Triple Camera| Nightography| Lag-free Gaming | Without Charger
# 4.0
# (4.4K)
# 300+ bought in past month
# Limited time deal
# ₹18,999
# M.R.P:
# ₹26,999 (30% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Sun, 29 Mar
# Add to cart
# POCO C71, Desert Gold (6GB, 128GB)
# 4.0
# (2.3K)
# 2K+ bought in past month
# ₹9,998
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Sun, 29 Mar
# Add to cart
# Redmi A5 Jaisalmer Gold (3GB RAM 64GB Storage) | Royale Design | Segment's Largest 17.47cm(6.88) and Smoothest 120Hz Display | 5200mAh Large Battery | Expandable Storage up to 2TB
# 4.1
# (393)
# 1K+ bought in past month
# ₹7,999
# M.R.P:
# ₹8,999 (11% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Sun, 29 Mar
# Add to cart
# iQOO 15R (Triumph Silver, 12GB RAM, 512GB Storage) | Snapdragon® 8 Gen 5 Processor | India’s Slimmest Smartphone in 7600mAh Battery* | Segment's Most Stable 144FPS Gaming*
# 4.2
# (238)
# 1K+ bought in past month
# ₹52,998
# M.R.P:
# ₹61,999 (15% off)
# FREE delivery Sun, 29 Mar
# Add to cart
# realme NARZO 90x 5G (Nitro Blue,6GB+128GB) | 7000mAh + 60W Biggest Battery & Fastest Charging in The Segment* | 144Hz Bright Display | Sony 50MP AI Rear Camera | AI Assist | 400% Ultra Boom Speaker
# 4.2
# (661)
# 1K+ bought in past month
# ₹15,499
# M.R.P:
# ₹16,499 (6% off)
# Save ₹500 with coupon
# FREE delivery Sun, 29 Mar
# Add to cart
# vivo V60e 5G (Elite Purple, 8GB RAM, 256GB Storage) with No Cost EMI/Additional Exchange Offers
# 4.3
# (457)
# 100+ bought in past month
# ₹33,999
# M.R.P:
# ₹36,999 (8% off)
# Flat INR 2500 Off on ICICI BankCards
# FREE delivery Sun, 29 Mar
# Add to cart
# OnePlus 13R| Smarter with OnePlus AI (12GB RAM, 256GB Storage Nebula Noir)
# 4.4
# (4.1K)
# 500+ bought in past month
# ₹39,996
# M.R.P:
# ₹44,999 (11% off)
# Save extra with No Cost EMI
# FREE delivery Sun, 29 Mar
# Add to cart
# Sponsored
# Samsung Galaxy S26 Plus 5G (Black, 12GB RAM, 256GB Storage), AI Phone, Photo Assist, Creative Studio, 50MP Camera, 4900mAh Battery and Super Fast Wireless Charging
# ₹1,19,999
# Flat INR 5000 Off on HDFC BankCards
# FREE delivery Sun, 29 Mar
# Add to cart
# +1 other color/pattern
# Sponsored
# Samsung Galaxy M36 5G Mobile (Orange Haze, 8GB RAM, 128GB Storage) | Google Gemini| Gorilla Glass Victus+ | 7.7mm | AI Enhanced 50MP OIS Triple Camera | Nightography| Lag-free Gaming | Without Charger
# 4.0
# (4.4K)
# 300+ bought in past month
# Limited time deal
# ₹18,999
# M.R.P:
# ₹26,999 (30% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Tue, 31 Mar
# Add to cart
# +2 other colors/patterns
# Motorola G57 Power 5G (Fluidity, 8GB RAM, 128GB Storage)| Snapdragon 6s Gen 4 Processor | 6.72" FHD+ Display | 50MP LYT-600 + 8MP Ultrawide | 8MP Selfie Camera | 7000mAh Battery, 33W TurboPower | IP64
# 4.2
# (183)
# 4K+ bought in past month
# ₹15,140
# M.R.P:
# ₹17,999 (16% off)
# FREE delivery Sun, 29 Mar
# Add to cart
# More Buying Choices
# ₹14,818(34 new offers)
# Samsung Galaxy S24 Snapdragon 5G (Onyx Black, 256 GB) (8 GB RAM)
# 4.3
# (231)
# 1K+ bought in past month
# ₹49,249
# M.R.P:
# ₹79,990 (38% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Sun, 29 Mar
# Add to cart
# Samsung Galaxy M17e 5G Mobile (Blitz Blue, 4GB RAM, 128GB Storage) | Smoothest 120 Hz Refresh Rate| Monster 6000 mAh Battery | IP54 | 6 Gen OS Upgrades | AI | Gemini Live | Without Charger
# ₹13,999
# M.R.P:
# ₹16,999 (18% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Sun, 29 Mar
# Add to cart
# VIVO T4 5G (Phantom Grey, 8GB RAM+256GB Storage) | Snapdragon 7s Gen 3 | 120Hz Quad-Curved AMOLED | 7300mAh+90W Fast Charge | 50MP Sony OIS Camera | Military Grade Build | AI Photo Enhance | AI Erase
# 4.2
# (334)
# 200+ bought in past month
# ₹25,950
# M.R.P:
# ₹27,999 (7% off)
# FREE delivery Wed, 1 Apr
# Only 1 left in stock.
# Add to cart
# +2
# Vivo T4x 5G (Marine Blue, 128 GB) (8 GB RAM)
# 4.4
# (3K)
# ₹18,399
# M.R.P:
# ₹19,499 (6% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Sun, 29 Mar
# Add to cart
# More Buying Choices
# ₹18,389(14 new offers)
# OPPO K14x 5G Smartphone, Prism Violet, 4GB RAM, 128GB Storage
# 5.0
# (1)
# ₹13,649
# M.R.P:
# ₹17,999 (24% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Sun, 29 Mar
# Add to cart
# iQOO Z10x 5G (Ultramarine, 8GB RAM, 128GB Storage) | 6500 mAh Large Capacity Battery | Dimensity 7300 Processor | Military-Grade Durability
# 4.4
# (10.8K)
# 1K+ bought in past month
# ₹18,998
# 10% Off on select cards
# FREE delivery Sun, 29 Mar
# Add to cart
# Samsung Galaxy A35 5G (Awesome Lilac, 8GB RAM, 128GB Storage) | Premium Glass Back | 50 MP Main Camera (OIS) | Nightography | IP67 | Corning Gorilla Glass Victus+ | sAMOLED with Vision Booster
# 4.2
# (593)
# 500+ bought in past month
# ₹24,999
# M.R.P:
# ₹33,999 (26% off)
# Up to 5% back with Amazon Pay ICI...
# FREE delivery Sun, 29 Mar
# Add to cart
# More Buying Choices
# ₹24,800(4 new offers)
# Sponsored
# iPhone Air 512 GB: Thinnest iPhone Ever, 16.63 cm (6.5″) Display with Promotion up to 120Hz, Powerful A19 Pro Chip, Center Stage Front Camera, All-Day Battery Life; Light Gold
# 3.0
# (2)
# ₹1,13,990
# M.R.P:
# ₹1,39,900 (19% off)
# Save extra with No Cost EMI
# FREE delivery Tue, 31 Mar
# Only 1 left in stock.
# Add to cart
# Sponsored
# iPhone 17 Pro 256 GB: 15.93 cm (6.3″) Display with Promotion up to 120Hz, A19 Pro Chip, Breakthrough Battery Life, Pro Fusion Camera System with Center Stage Front Camera; Cosmic Orange
# 4.5
# (347)
# 500+ bought in past month
# ₹1,34,900
# Save extra with No Cost EMI
# FREE delivery Mon, 30 Mar
# Only 2 left in stock.
# Add to cart
# +1 other color/pattern

# %%
print(f"TOTAL ITEMS IN THE WEB PAGE FOR '{search}' ARE : ", len(lists))
# Out:
# TOTAL ITEMS IN THE WEB PAGE FOR 'mobiles' ARE :  76

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### **To avoid being blocked by the website you should first save the entire html in a file**

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time

options = Options()
options.add_experimental_option("detach", True) 

# -----------------------------------------------
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)

options.add_argument("--disable-blink-features=AutomationControlled")

options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36")
# -----------------------------------------------


brave_path = r"C:\Users\biswa\AppData\Local\BraveSoftware\Brave-Browser\Application\brave.exe"
options.binary_location = brave_path


driver = webdriver.Chrome(options=options)

search = "phones"
num = 0

for i in range(1, 20):
    driver.get(f"https://www.amazon.in/s?k={search}&page={i}&xpid=7X1j0yjYU1Dx7&crid=248K4SV2XN0VI&qid=1774618904&sprefix=phone%2Caps%2C408&ref=sr_pg_2")

    elems = driver.find_elements(By.CLASS_NAME, "puis-card-container")
    print(len(elems), f"ITEMS FOUND at the page {i}")

    for i in elems:
        raw_html = i.get_attribute("outerHTML")

        # using beautiful soup to convert raw html into a proper html format
        # if you dont use beautiful soup it will just give the html in one single line
        soup = BeautifulSoup(raw_html, "html.parser")
        clean_html = soup.prettify()

        # saving the files into 'amazon web scrapping data' folder
        # make sure 'amazon web scrapping data' folder is already created
        with open(f"amazon web scrapping data/{search}-{num}.html", "w", encoding="utf-8") as f:
            f.write(clean_html)
            num += 1

driver.close()
# Out:
# 27 ITEMS FOUND at the page 1
# 22 ITEMS FOUND at the page 2
# 22 ITEMS FOUND at the page 3
# 22 ITEMS FOUND at the page 4
# 22 ITEMS FOUND at the page 5
# 22 ITEMS FOUND at the page 6
# 22 ITEMS FOUND at the page 7
# 22 ITEMS FOUND at the page 8
# 22 ITEMS FOUND at the page 9
# 22 ITEMS FOUND at the page 10
# 20 ITEMS FOUND at the page 11
# 20 ITEMS FOUND at the page 12
# 20 ITEMS FOUND at the page 13
# 20 ITEMS FOUND at the page 14
# 20 ITEMS FOUND at the page 15
# 20 ITEMS FOUND at the page 16
# 20 ITEMS FOUND at the page 17
# 20 ITEMS FOUND at the page 18
# 20 ITEMS FOUND at the page 19
