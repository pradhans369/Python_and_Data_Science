# %% [markdown]
# # import dataset

# %%
import numpy as np
import pandas as pd

# this is a dataset imported from kaggle
df = pd.read_csv("students_1000.csv")
df
# Out:
#                name  cgpa   iq  placement
# 0       Isha Sharma  7.75  126          1
# 1     Sneha Agarwal  7.05  121          1
# 2          Riya Rao  7.91  110          1
# 3      Saanvi Ghosh  8.88  102          1
# 4      Rakesh Patel  6.94  118          0
# ..              ...   ...  ...        ...
# 995    Sameer Joshi  6.89  122          1
# 996   Aryan Agarwal  9.18  109          1
# 997  Rakesh Agarwal  7.90   99          1
# 998     Mohit Kohli  6.57  108          1
# 999     Nikhil Jain  7.83  101          1
#
# [1000 rows x 4 columns]

# %%
df = df.iloc[:, 1:]
df
# Out:
#      cgpa   iq  placement
# 0    7.75  126          1
# 1    7.05  121          1
# 2    7.91  110          1
# 3    8.88  102          1
# 4    6.94  118          0
# ..    ...  ...        ...
# 995  6.89  122          1
# 996  9.18  109          1
# 997  7.90   99          1
# 998  6.57  108          1
# 999  7.83  101          1
#
# [1000 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       1000 non-null   float64
#  1   iq         1000 non-null   int64
#  2   placement  1000 non-null   int64
# dtypes: float64(1), int64(2)
# memory usage: 23.6 KB

# %%
# 1 - preprocessing + EDA (exploratory data analysis) + feature selection
# 2 - extract input and output col
# 3 - scale the values
# 4 - traing test split / cross validation
# 5 - train the model
# 6 - evaluate the model / model selection
# 7 - deploy the model

# %%
import matplotlib.pyplot as plt

plt.scatter(df["cgpa"], df["iq"], c = df["placement"])

# %% [markdown]
# Extracting input and output col

# %%
# storing the independent and dependent data sets into different variables
a = df.iloc[:, 0:2]
b = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split

train_test_split(a, b, test_size=0.1)
# first variable a represents x axis, and the second variable b represents y axis
# when you write test_size = 0.1 that means out all the datas 10 percent of data to be used for 'testing' and rest of the data should be used for 'training'
# here it will give 4 outputs training and test data of a and training and test data of b, in total it will give 4 data sets you can store them into four different variables
# remember the order it will give data first it will give train and test data of a and then it will give train and test data of b


# storing the data into four different variables
x_train, x_test, y_train, y_test = train_test_split(a, b, test_size=0.1)

# %%
x_train
# Out:
#      cgpa   iq
# 380  6.28  118
# 958  7.83  122
# 228  6.41  121
# 698  8.22  116
# 358  7.55   92
# ..    ...  ...
# 347  5.65  121
# 472  5.53  108
# 708  4.91  108
# 384  6.36  118
# 381  6.54  104
#
# [900 rows x 2 columns]

# %%
x_test  # since we took 10% of data out of 100 datas it will only store 10% data which is 100 rows
# Out:
#      cgpa   iq
# 100  5.64  121
# 188  6.27  116
# 684  5.86   95
# 842  5.97  103
# 413  8.61  135
# ..    ...  ...
# 342  7.47  115
# 134  6.19  107
# 494  8.88  128
# 846  7.52  125
# 204  5.68  110
#
# [100 rows x 2 columns]

# %%
y_train
# Out:
# 380    0
# 958    0
# 228    1
# 698    1
# 358    0
#       ..
# 347    0
# 472    1
# 708    0
# 384    1
# 381    1
# Name: placement, Length: 900, dtype: int64

# %%
y_test
# Out:
# 100    1
# 188    0
# 684    1
# 842    1
# 413    1
#       ..
# 342    1
# 134    1
# 494    1
# 846    0
# 204    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_train
# Out:
# array([[-0.90089841,  0.62653099],
#        [ 0.55305451,  0.96327502],
#        [-0.77895397,  0.87908901],
#        ...,
#        [-2.18600518, -0.2153291 ],
#        [-0.82585568,  0.62653099],
#        [-0.65700953, -0.55207314]], shape=(900, 2))

# %%
x_test = scaler.transform(x_test)
x_test
# Out:
# array([[-1.50124026,  0.87908901],
#        [-0.91027875,  0.45815897],
#        [-1.29487275, -1.30974722],
#        [-1.191689  , -0.63625915],
#        [ 1.28472114,  2.05769314],
#        [-0.037907  ,  0.87908901],
#        [ 0.6656186 , -0.13114309],
#        [ 0.76880236, -1.05718919],
#        [-0.10356939,  0.20560094],
#        [-1.44495821, -1.64649125],
#        [ 0.30916563, -0.72044516],
#        [ 0.2341229 , -0.29951511],
#        [-0.11294973,  0.20560094],
#        [ 1.50984933,  0.62653099],
#        [-0.48816339, -0.88881717],
#        [-0.29117622,  0.54234498],
#        [-0.88213773, -0.38370112],
#        [-0.92903944,  0.12141493],
#        [ 0.18722119, -0.72044516],
#        [-0.90089841, -0.13114309],
#        [-0.15985144,  0.96327502],
#        [-0.62886851, -0.88881717],
#        [ 0.16846051,  0.45815897],
#        [ 0.46863143, -1.1413752 ],
#        [ 1.89444333,  1.46839107],
#        [ 1.55675104,  0.71071699],
#        [-1.96087699,  0.20560094],
#        [ 0.06527675, -0.13114309],
#        [ 0.79694338,  0.45815897],
#        [-0.01914632,  0.12141493],
#        [ 0.15908017,  0.87908901],
#        [ 0.86260577, -0.72044516],
#        [-0.81647534,  0.12141493],
#        [-0.62886851, -0.2153291 ],
#        [-0.99470183, -2.82509538],
#        [-0.46940271, -0.2153291 ],
#        [ 0.6656186 , -1.22556121],
#        [-1.39805651, -1.56230524],
#        [-1.98901801, -0.46788713],
#        [-0.64762919, -0.13114309],
#        [-0.5819668 , -0.72044516],
#        [ 1.60365274,  1.80513511],
#        [ 0.14969983,  0.03722892],
#        [-0.28179588,  0.62653099],
#        [ 0.38420836, -1.64649125],
#        [-1.58566333,  0.37397296],
#        [-1.75450948, -1.89904928],
#        [ 0.45925109, -0.55207314],
#        [-1.85769324,  1.30001906],
#        [-0.39435998, -0.46788713],
#        [-0.46940271, -2.99346739],
#        [-0.5819668 ,  1.30001906],
#        [-0.422501  , -1.05718919],
#        [-0.54444544, -1.30974722],
#        [ 1.37852455, -2.0674213 ],
#        [ 0.62809724, -0.04695708],
#        [ 1.98824674, -0.2153291 ],
#        [-1.74512914, -0.46788713],
#        [-0.50692407,  1.04746103],
#        [-0.5819668 ,  0.45815897],
#        [-0.29117622, -0.46788713],
#        [-0.33807793, -1.1413752 ],
#        [ 0.52491348, -0.63625915],
#        [-0.61010783,  1.21583305],
#        [ 0.45925109, -1.64649125],
#        [ 1.67869548,  0.87908901],
#        [ 0.70313997,  0.28978695],
#        [-0.90089841,  1.30001906],
#        [-1.27611207,  0.62653099],
#        [-1.60442402,  0.71071699],
#        [-0.5819668 , -1.30974722],
#        [-0.807095  ,  0.87908901],
#        [-0.07542837,  1.13164704],
#        [-0.54444544, -0.55207314],
#        [-1.36053514,  0.62653099],
#        [-2.13910348,  0.71071699],
#        [ 0.14969983, -1.47811924],
#        [ 1.35976387, -0.88881717],
#        [ 0.86260577, -2.57253735],
#        [ 1.36914421, -0.04695708],
#        [-0.57258646, -0.63625915],
#        [ 0.42172973, -0.80463116],
#        [ 0.38420836, -0.55207314],
#        [-0.62886851,  1.21583305],
#        [ 0.08403744,  0.20560094],
#        [ 1.48170831, -1.89904928],
#        [-1.43557787,  0.62653099],
#        [-1.06036422,  0.20560094],
#        [ 1.5942724 , -1.22556121],
#        [-1.40743685,  0.12141493],
#        [-1.4637189 ,  1.55257708],
#        [ 1.03145192, -2.48835134],
#        [-0.87275739,  0.28978695],
#        [ 0.60933656, -1.30974722],
#        [-1.09788558, -1.05718919],
#        [ 0.21536222,  0.37397296],
#        [-0.98532148, -0.29951511],
#        [ 1.53799035,  1.46839107],
#        [ 0.26226392,  1.21583305],
#        [-1.4637189 , -0.04695708]])
