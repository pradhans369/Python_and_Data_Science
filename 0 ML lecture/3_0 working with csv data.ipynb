# %% [markdown]
# # Working with CSV data

# %% [markdown]
# Datas are available in CSV, JSON, SQL, through API, WebScrapping

# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv("aug_test.csv")
df
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# ...

# %%
# sep parameter

a = pd.read_csv("student tsv file.tsv")
a
# Out:
#       Name\tCGPA\tIQ\tPlacement
# 0      Student_1\t6.87\t73.0\t1
# 1     Student_2\t9.75\t121.0\t0
# 2      Student_3\t8.66\t95.0\t0
# 3     Student_4\t7.99\t111.0\t1
# 4     Student_5\t5.78\t143.0\t1
# ..                          ...
# 95    Student_96\t7.47\t98.0\t1
# 96   Student_97\t7.61\t128.0\t1
# 97   Student_98\t7.14\t142.0\t0
# 98   Student_99\t5.13\t141.0\t1
# 99  Student_100\t5.54\t132.0\t0
#
# [100 rows x 1 columns]

# %%
# sep parameter

a = pd.read_csv("student tsv file.tsv", sep="\t")
a
# Out:
#            Name  CGPA     IQ  Placement
# 0     Student_1  6.87   73.0          1
# 1     Student_2  9.75  121.0          0
# 2     Student_3  8.66   95.0          0
# 3     Student_4  7.99  111.0          1
# 4     Student_5  5.78  143.0          1
# ..          ...   ...    ...        ...
# 95   Student_96  7.47   98.0          1
# 96   Student_97  7.61  128.0          1
# 97   Student_98  7.14  142.0          0
# 98   Student_99  5.13  141.0          1
# 99  Student_100  5.54  132.0          0
#
# [100 rows x 4 columns]

# %%
# use_cols parameter -- used to import only the required columns

df = pd.read_csv("aug_test.csv", usecols=['enrollee_id', 'relevent_experience', 'experience', 'training_hours'])

df
# Out:
#       enrollee_id      relevent_experience experience  training_hours
# 0           32403  Has relevent experience          9              21
# 1            9858  Has relevent experience          5              98
# 2           31806   No relevent experience         <1              15
# 3           27385  Has relevent experience         11              39
# 4           27724  Has relevent experience        >20              72
# ...           ...                      ...        ...             ...
# 2124         1289   No relevent experience         16              15
# 2125          195  Has relevent experience         18              30
# 2126        31762   No relevent experience          3              18
# 2127         7873  Has relevent experience          7              84
# 2128        12215  Has relevent experience         15              11
#
# [2129 rows x 4 columns]

# %%
# squeeze parameter

pd.read_csv("aug_test.csv", usecols=['enrollee_id'], squeeze=True)      # it will throw error bcoz "squeeze" has been removed from recent version of pandas
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # squeeze parameter
# ----> 3 pd.read_csv("aug_test.csv", usecols=['enrollee_id'], squeeze=True)      # it will throw error bcoz "squeeze" has been removed from recent version of pandas
#
# TypeError: read_csv() got an unexpected keyword argument 'squeeze'

# %%
# skiprows parameter

pd.read_csv("aug_test.csv", skiprows=[0,5])            # will remove the rows idx 0 and 5
# Out:
#       32403   city_41  0.8270000000000001    Male  Has relevent experience  \
# 0      9858  city_103               0.920  Female  Has relevent experience
# 1     31806   city_21               0.624    Male   No relevent experience
# 2     27385   city_13               0.827    Male  Has relevent experience
# 3       217   city_23               0.899    Male   No relevent experience
# 4     21465   city_21               0.624     NaN  Has relevent experience
# ...     ...       ...                 ...     ...                      ...
# 2122   1289  city_103               0.920    Male   No relevent experience
# 2123    195  city_136               0.897    Male  Has relevent experience
# 2124  31762  city_100               0.887    Male   No relevent experience
# 2125   7873  city_102               0.804    Male  Has relevent experience
# 2126  12215  city_102               0.804    Male  Has relevent experience
#
#       Full time course        Graduate        STEM   9      <10  \
# ...

# %%
# nrows parameter   -- used to show a specific number of rows

pd.read_csv("aug_test.csv", nrows = 10)     # will import number of rows entered here (10 rows in this case)

# this scenario is used when there is around billions of data, and its not practical to download all those datas in your computer. In such scenarios 'nrows' is used
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
# 2        31806   city_21                   0.624    Male
# 3        27385   city_13                   0.827    Male
# 4        27724  city_103                   0.920    Male
# 5          217   city_23                   0.899    Male
# 6        21465   city_21                   0.624     NaN
# 7        27302  city_160                   0.920  Female
# 8        12994  city_173                   0.878    Male
# 9        16287   city_21                   0.624    Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience    Full time course        Graduate
# 1  Has relevent experience       no_enrollment        Graduate
# 2   No relevent experience       no_enrollment     High School
# 3  Has relevent experience       no_enrollment         Masters
# ...

# %%
# on_bad_liens -- used to remove the bad lines from the code

pd.read_csv("bad_lines.csv", on_bad_lines = "skip")
# Out:
#     name  age       city
# 0   Amit   25      Delhi
# 1  Priya   28     Mumbai
# 2  Sneha   30        NaN
# 3    Raj   27  Bangalore

# %%
# dtypes parameter

# pd.read_csv("aug_test.csv", dtype={"index_name":int})         # it is used to convert a float data type column into a integer data type column

# %%
# handling dates

# by default dates are in object (string) format in pd, hence to use all the functionalities of the dates you have to convert it into the dates that the machine can recognise

pd.read_excel("IPL_2020.xlsx", parse_dates=['date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 812 entries, 0 to 811
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     812 non-null    int64
#  1   season                 812 non-null    int64
#  2   city                   805 non-null    object
#  3   date                   812 non-null    datetime64[ns]
#  4   team1                  812 non-null    object
#  5   Pplay T1               812 non-null    int64
#  6   pplay twick1           812 non-null    int64
#  7   team2                  812 non-null    object
#  8   Pplay T2               812 non-null    int64
#  9   pplay twick2           812 non-null    int64
#  10  toss_winner            812 non-null    object
#  11  toss_decision          812 non-null    object
#  12  result                 812 non-null    object
#  13  dl_applied             812 non-null    int64
# ...

# %%
# convertes

def rename(name):
    if name == "Royal Challengers Bangalore":
        return "RCB"
    elif name == "Mumbai Indians":
        return "MI"
    else:
        return name

pd.read_excel("IPL_2020.xlsx")
# Out:
#         id  season       city       date                        team1  \
# 0        1    2017  Hyderabad 2017-04-05          Sunrisers Hyderabad
# 1        2    2017       Pune 2017-04-06               Mumbai Indians
# 2        3    2017     Rajkot 2017-04-07                Gujarat Lions
# 3        4    2017     Indore 2017-04-08       Rising Pune Supergiant
# 4        5    2017  Bangalore 2017-04-08  Royal Challengers Bangalore
# ..     ...     ...        ...        ...                          ...
# 807  20256    2020    Sharjah 2020-11-03          Sunrisers Hyderabad
# 808  20257    2020      Dubai 2020-11-05               Mumbai Indians
# 809  20258    2020  Abu Dhabi 2020-11-06          Sunrisers Hyderabad
# 810  20259    2020  Abu Dhabi 2020-11-08               Delhi Capitals
# 811  20260    2020      Dubai 2020-11-10               Mumbai Indians
#
#      Pplay T1  pplay twick1                        team2  Pplay T2  \
# ...

# %%
pd.read_excel("IPL_2020.xlsx", converters={'team1' : rename})   # it will rename all the text which is "Royal Challenges Bangalore" into "RCB"
# Out:
#         id  season       city       date                   team1  Pplay T1  \
# 0        1    2017  Hyderabad 2017-04-05     Sunrisers Hyderabad        59
# 1        2    2017       Pune 2017-04-06                      MI        61
# 2        3    2017     Rajkot 2017-04-07           Gujarat Lions        52
# 3        4    2017     Indore 2017-04-08  Rising Pune Supergiant        35
# 4        5    2017  Bangalore 2017-04-08                     RCB        41
# ..     ...     ...        ...        ...                     ...       ...
# 807  20256    2020    Sharjah 2020-11-03     Sunrisers Hyderabad        56
# 808  20257    2020      Dubai 2020-11-05                      MI        63
# 809  20258    2020  Abu Dhabi 2020-11-06     Sunrisers Hyderabad        48
# 810  20259    2020  Abu Dhabi 2020-11-08          Delhi Capitals        65
# 811  20260    2020      Dubai 2020-11-10                      MI        61
#
# ...

# %%
# na_values -- to convert any value into 'NaN'

a = pd.read_csv("aug_test.csv", na_values=['Male'])
a.head(100)
# Out:
#     enrollee_id      city  city_development_index  gender  \
# 0         32403   city_41                   0.827     NaN
# 1          9858  city_103                   0.920  Female
# 2         31806   city_21                   0.624     NaN
# 3         27385   city_13                   0.827     NaN
# 4         27724  city_103                   0.920     NaN
# ..          ...       ...                     ...     ...
# 95         2934   city_75                   0.939     NaN
# 96        12919  city_103                   0.920  Female
# 97         4386   city_21                   0.624     NaN
# 98        22462   city_21                   0.624     NaN
# 99        13988  city_103                   0.920     NaN
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience    Full time course        Graduate
# 1   Has relevent experience       no_enrollment        Graduate
# 2    No relevent experience       no_enrollment     High School
# ...

# %%
pd.read_csv("aug_test.csv")
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# ...

# %%
# loading a huge dataset in chunks

# currently this file holds 2129 rows and 13 cols. it will divide the data set into a chunk of 500 data set each
# this method is practical when working on a big data set bcoz downloading a bigger data on your computer and working on it might lead to breakdown of your computer

chunks = pd.read_csv("aug_test.csv", chunksize=500)

for n, i in enumerate(chunks, start = 1):
    print(f"chunk {n} : {i.shape}")
# Out:
# chunk 1 : (500, 13)
# chunk 2 : (500, 13)
# chunk 3 : (500, 13)
# chunk 4 : (500, 13)
# chunk 5 : (129, 13)
