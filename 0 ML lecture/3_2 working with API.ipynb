# %% [markdown]
# # Working with API

# %%
# API
import pandas as pd
import requests

# %%
url = "https://covid-193.p.rapidapi.com/countries"
headers = {
    'x-rapidapi-host': 'covid-193.p.rapidapi.com',                              # identifies which API you are calling
	'x-rapidapi-key': '3d72a3ed40mshf6f339ded999111p1a51e5jsn1003e2db0078'      # authenticates your access (your API key)
}

a = requests.get(url, headers = headers)        # headers=headers means you are passing a variable named headers as the value for the headers parameter in the requests.get() function.
data = a.json()

data
# Out:
# {'get': 'countries',
#  'parameters': [],
#  'errors': [],
#  'results': 231,
#  'response': ['Afghanistan',
#   'Albania',
#   'Algeria',
#   'Andorra',
#   'Angola',
#   'Anguilla',
#   'Antigua-and-Barbuda',
#   'Argentina',
#   'Armenia',
#   'Aruba',
#   'Australia',
#   'Austria',
#   'Azerbaijan',
#   'Bahamas',
#   'Bahrain',
#   'Bangladesh',
#   'Barbados',
#   'Belarus',
#   'Belgium',
#   'Belize',
#   'Benin',
#   'Bermuda',
#   'Bhutan',
#   'Bolivia',
#   'Bosnia-and-Herzegovina',
#   'Botswana',
#   'Brazil',
#   'British-Virgin-Islands',
#   'Brunei',
#   'Bulgaria',
#   'Burkina-Faso',
#   'Burundi',
#   'Cabo-Verde',
#   'Cambodia',
#   'Cameroon',
#   'Canada',
#   'CAR',
#   'Caribbean-Netherlands',
#   'Cayman-Islands',
#   'Chad',
#   'Channel-Islands',
#   'Chile',
#   'China',
#   'Colombia',
#   'Comoros',
#   'Congo',
#   'Cook-Islands',
#   'Costa-Rica',
#   'Croatia',
#   'Cuba',
#   'Cura&ccedil;ao',
#   'Cyprus',
#   'Czechia',
#   'Denmark',
# ...

# %%
# read the html above and you will find that all the countries names are in 'response' column

data['response']        # printing a specific column of the data
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antigua-and-Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia-and-Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British-Virgin-Islands',
#  'Brunei',
#  'Bulgaria',
#  'Burkina-Faso',
#  'Burundi',
#  'Cabo-Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'CAR',
#  'Caribbean-Netherlands',
#  'Cayman-Islands',
#  'Chad',
#  'Channel-Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Cook-Islands',
#  'Costa-Rica',
#  'Croatia',
#  'Cuba',
#  'Cura&ccedil;ao',
#  'Cyprus',
#  'Czechia',
#  'Denmark',
#  'Diamond-Princess',
#  'Djibouti',
#  'Dominica',
#  'Dominican-Republic',
#  'DPRK',
#  'DRC',
#  'Ecuador',
#  'Egypt',
#  'El-Salvador',
# ...

# %%
pd.DataFrame(data['response'])         # converting api data into pandas data frame
# Out:
#                      0
# 0          Afghanistan
# 1              Albania
# 2              Algeria
# 3              Andorra
# 4               Angola
# ..                 ...
# 226  Wallis-and-Futuna
# 227     Western-Sahara
# 228              Yemen
# 229             Zambia
# 230           Zimbabwe
#
# [231 rows x 1 columns]

# %%
url2 = "https://tourism-and-economic-impact.p.rapidapi.com/list"

payload = {}
headers2 = {
	"x-rapidapi-key": "3d72a3ed40mshf6f339ded999111p1a51e5jsn1003e2db0078",
	"x-rapidapi-host": "tourism-and-economic-impact.p.rapidapi.com",
	"Content-Type": "application/x-www-form-urlencoded"
}

response = requests.post(url2, data=payload, headers=headers2)


economy = response.json()
economy
# below we will be writing a code to convert this api key request into a pandas dataframe project
# Out:
# {'result': {'current_page': 1,
#   'data': [{'country': 'Aruba',
#     'country_code': 'ABW',
#     'year': 1999,
#     'tourism_receipts': 782000000,
#     'tourism_arrivals': 972000,
#     'tourism_exports': 62.5429,
#     'tourism_departures': '',
#     'tourism_expenditures': 9.49539,
#     'gdp': 1722910000,
#     'inflation': 2.28037,
#     'unemployment': ''},
#    {'country': 'Africa Eastern and Southern',
#     'country_code': 'AFE',
#     'year': 1999,
#     'tourism_receipts': 8034210000,
#     'tourism_arrivals': 15309400,
#     'tourism_exports': 12.204,
#     'tourism_departures': '',
#     'tourism_expenditures': 7.76054,
#     'gdp': 265429000000,
#     'inflation': 7.81986,
#     'unemployment': ''},
#    {'country': 'Afghanistan',
#     'country_code': 'AFG',
#     'year': 1999,
#     'tourism_receipts': None,
#     'tourism_arrivals': None,
#     'tourism_exports': None,
#     'tourism_departures': '',
#     'tourism_expenditures': None,
#     'gdp': None,
# ...

# %%
# below we have converted 'economy' data into the pandas data frame
pd.DataFrame(economy['result']['data'])     # results --> data (inside)
# Out:
#                            country country_code  year  tourism_receipts  \
# 0                            Aruba          ABW  1999      7.820000e+08
# 1      Africa Eastern and Southern          AFE  1999      8.034210e+09
# 2                      Afghanistan          AFG  1999               NaN
# 3       Africa Western and Central          AFW  1999      1.443610e+09
# 4                           Angola          AGO  1999      3.100000e+07
# 5                          Albania          ALB  1999      2.180000e+08
# 6                          Andorra          AND  1999               NaN
# 7                       Arab World          ARB  1999               NaN
# 8             United Arab Emirates          ARE  1999      8.930000e+08
# 9                        Argentina          ARG  1999      3.175000e+09
# 10                         Armenia          ARM  1999      4.700000e+07
# 11                  American Samoa          ASM  1999               NaN
# ...

# %%
# importing only the required data and storing it in a object and making a csv file of it and uploading it on 'kaggle'

my_data = pd.DataFrame(economy['result']['data'], columns=['country', 'year', 'gdp', 'inflation', 'unemployment'])
my_data.to_csv('country and their economic dynaics.csv', index = False)

# %%
data = pd.DataFrame(economy['result']['data'])
data.iloc[:, [0,2,4,7,8,9,10]]
# Out:
#                            country  year  tourism_arrivals  \
# 0                            Aruba  1999          972000.0
# 1      Africa Eastern and Southern  1999        15309400.0
# 2                      Afghanistan  1999               NaN
# 3       Africa Western and Central  1999         3897980.0
# 4                           Angola  1999           45000.0
# 5                          Albania  1999          371000.0
# 6                          Andorra  1999         9422000.0
# 7                       Arab World  1999               NaN
# 8             United Arab Emirates  1999               NaN
# 9                        Argentina  1999         2898000.0
# 10                         Armenia  1999           41000.0
# 11                  American Samoa  1999           41000.0
# 12             Antigua and Barbuda  1999          560000.0
# 13                       Australia  1999         4459000.0
# 14                         Austria  1999        17467000.0
# ...
