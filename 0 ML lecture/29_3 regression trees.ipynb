# %% [markdown]
# # **Regression Trees**

# %% [markdown]
# Where decision treee is applied on non-classification data, then its called Regression Trees.
#
# You apply regression trees when there is non-linear relationship in the data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Visit the link for better understanding :** https://youtu.be/g9c66TUylZ4?si=0WnFQq9MFcI6jMT6
