# %% [markdown]
# # **Ridge Regression using Gradient Descent**

# %% [markdown]
# > So far we have been learning ridge reg on linear reg. Now we will be learning ridge reg using Gradient descent.

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, SGDRegressor      
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import make_regression

X, y = make_regression(n_samples=10000, n_features=5, noise=0.2, random_state=42)

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=45)

# making prediction using SGDRegressor
reg = SGDRegressor(penalty='l2', max_iter=500, eta0=0.1, learning_rate='constant', alpha=0.001)
# since you are using penaly = 'l2', it automatically becomes SGDRegressor along with ridge regression. Bcoz, l2 represents 'ridge'
# refer 20_4_2 for all the parameters of SGDRegressor

reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)

print("R2 score : ",r2_score(y_test,y_pred), '\n')
print(reg.coef_)
print(reg.intercept_)
# Out:
# R2 score :  0.9999947510459462
#
# [91.24610965 94.65028423  0.20713585 38.14855782  5.36767082]
# [0.02818449]

# %%
# making the same prediction using Ridge regression 

reg = Ridge(alpha=0.001, max_iter=500,solver='sparse_cg')
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)

print("R2 score",r2_score(y_test,y_pred))
print(reg.coef_)
print(reg.intercept_)
# Out:
# R2 score 0.9999978286743694
# [91.40414487 94.77493032  0.275934   38.25557938  5.35637056]
# -3.921551459118433e-06
