# %% [markdown]
# # **Ridge Regression using Gradient Descent**

# %% [markdown]
# > So far we have been learning ridge reg on linear reg. Now we will be learning ridge reg using Gradient descent.

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, SGDRegressor      
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import load_diabetes


X,y = load_diabetes(return_X_y=True)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=4)

# making prediction using SGDRegressor
reg = SGDRegressor(penalty='l2', max_iter=500, eta0=0.1, learning_rate='constant', alpha=0.001)
# since you are using penaly = 'l2', it automatically becomes SGDRegressor along with ridge regression. Bcoz, l2 represents 'ridge'
# refer 20_4_2 for all the parameters of SGDRegressor
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)

print("R2 score : ",r2_score(y_test,y_pred), '\n')
print(reg.coef_)
print(reg.intercept_)
# Out:
# R2 score :  0.45603352506535577
#
# [  51.04873939 -153.86890214  364.90937157  269.50984774   -5.61677323
#   -58.8951253  -167.39972791  135.24837512  328.22156857   98.56398319]
# [151.87066474]

# %%
# making the same prediction using Ridge regression 

reg = Ridge(alpha=0.001, max_iter=500,solver='sparse_cg')
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)

print("R2 score",r2_score(y_test,y_pred))
print(reg.coef_)
print(reg.intercept_)
# Out:
# R2 score 0.46250101621576734
# [  34.52193655 -290.84083104  482.40182913  368.06788094 -852.44871472
#   501.59162034  180.11114301  270.7633618   759.73536409   37.49137054]
# 151.10198521305708
