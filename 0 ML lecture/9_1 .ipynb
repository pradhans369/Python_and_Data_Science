# %% [markdown]
# ### Using Pickle

# %% [markdown]
# The code down below is the production code, which you will be using while working in a corporate. And the code we wrote in 9_0 was the code that the data scientist has to write on his computer, and then upload the encoders and predictions on the file.

# %%
import pickle
import numpy as np
import pandas as pd

# %%
ohe_sex = pickle.load(open('models/ohe_sex.pkl', 'rb'))
ohe_embarked = pickle.load(open('models/ohe_embarked.pkl', 'rb'))
clf = pickle.load(open('models/clf.pkl', 'rb'))
col = pickle.load(open('models/col.pkl', 'rb'))

# making new user input
# Pclass/gender/age/SibSp/Parch/Fare/Embarked
test_input = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'], dtype=object).reshape(1, 7)


# using ohe hot encoding on sex and embarked which is imported from 9_0 file
# this 'sex' holds both the columns for male and female
test_input_sex = ohe_sex.transform(test_input[:, 1].reshape(1, 1))
test_input_embarked = ohe_embarked.transform(test_input[:, -1].reshape(1, 1))


test_input_age = test_input[:, 2].reshape(1, 1)


# concanating all the columns into one column
test_input_transformed = np.concat((test_input[:, [0,3,4,5]], test_input_age, test_input_sex, test_input_embarked), axis=1)
test_input_transformed
# Out:
# C:\Users\biswa\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# C:\Users\biswa\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# array([[2, 0, 0, 10.5, 31.0, 0.0, 1.0, 0.0, 0.0, 1.0]], dtype=object)

# %%
# converting into data frame and naming them with columns

# we are using 'col' which is imported from 9_0
test_input_transformed = pd.DataFrame(test_input_transformed, columns=col)
test_input_transformed
# Out:
#   Pclass SibSp Parch  Fare   Age Sex_female Sex_male Embarked_C Embarked_Q  \
# 0      2     0     0  10.5  31.0        0.0      1.0        0.0        0.0
#
#   Embarked_S
# 0        1.0

# %%
# making prediction
clf.predict(test_input_transformed)
# as the ans is showing 0, that means the given person will die
# Out:
# C:\Users\biswa\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# array([0])

# %% [markdown]
# If there is any change in the codes in 9_0 you have to make changes in the codes of 9_1, which is totally not efficient.

# %% [markdown]
# The codes we wrote in 9_0 and in 9_1 is not an efficient way to write production grade codes, coz we haven't used pipelines. Now in 9_2 and 9_3 we will rewrite the code using pipeline and will make a good code.
