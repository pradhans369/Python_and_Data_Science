# %% [markdown]
# # Normalization vs Standardization

# %%
# before doing scaling first you need to check that, is feature scaling required ?
# once you are sure, that scaling is required then you need to decide that wheather to use normalization or standardizati
# normalization is used where you alredy know the min and max values
