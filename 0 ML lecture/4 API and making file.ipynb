# %%
import requests
import pandas as pd

# %%
url = "https://daily-petrol-diesel-lpg-cng-fuel-prices-in-india.p.rapidapi.com/v1/fuel-prices/history/india/maharashtra/mumbai"

headers = {
	"x-rapidapi-key": "3d72a3ed40mshf6f339ded999111p1a51e5jsn1003e2db0078",
	"x-rapidapi-host": "daily-petrol-diesel-lpg-cng-fuel-prices-in-india.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

response = response.json()

# %%
response
# Out:
# {'cityId': 'mumbai',
#  'cityName': 'Mumbai',
#  'stateId': 'maharashtra',
#  'stateName': 'Maharashtra',
#  'countryId': 'india',
#  'countryName': 'India',
#  'history': [{'applicableOn': '2025-07-15',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-07-16',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-07-17',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-07-18',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-07-19',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-07-20',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-07-21',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-07-22',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-07-23',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-07-24',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-07-25',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-07-26',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-07-27',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-07-28',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-07-29',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-07-30',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-07-31',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-08-01',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-08-02',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-08-03',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-08-04',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-08-05',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-08-06',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-08-07',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-08-08',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-08-09',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-08-10',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-08-11',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-08-12',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}},
#   {'applicableOn': '2025-08-13',
#    'fuel': {'petrol': {'retailPrice': 103.49,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'diesel': {'retailPrice': 90.01,
#      'retailPriceChange': 0,
#      'retailUnit': 'litre',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'day'},
#     'cng': {'retailPrice': 78,
#      'retailPriceChange': 2,
#      'retailUnit': 'kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'},
#     'lpg': {'retailPrice': 852.5,
#      'retailPriceChange': 0,
#      'retailUnit': '14.2kg',
#      'currency': 'INR',
#      'retailPriceChangeInterval': 'month'}}}]}

# %%
data = pd.DataFrame(response['history'])
data
# Out:
#    applicableOn                                               fuel
# 0    2025-07-15  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 1    2025-07-16  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 2    2025-07-17  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 3    2025-07-18  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 4    2025-07-19  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 5    2025-07-20  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 6    2025-07-21  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 7    2025-07-22  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 8    2025-07-23  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 9    2025-07-24  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 10   2025-07-25  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 11   2025-07-26  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 12   2025-07-27  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 13   2025-07-28  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 14   2025-07-29  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 15   2025-07-30  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 16   2025-07-31  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 17   2025-08-01  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 18   2025-08-02  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 19   2025-08-03  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 20   2025-08-04  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 21   2025-08-05  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 22   2025-08-06  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 23   2025-08-07  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 24   2025-08-08  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 25   2025-08-09  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 26   2025-08-10  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 27   2025-08-11  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 28   2025-08-12  {'petrol': {'retailPrice': 103.49, 'retailPric...
# 29   2025-08-13  {'petrol': {'retailPrice': 103.49, 'retailPric...

# %%
print(type(response['history']))
print(response)

# hence history is a list not a dictionary we have to write the code bit differently
# Out:
# <class 'list'>

# %%
date = data.iloc[:, 0]
date
# Out:
# 0     2025-07-15
# 1     2025-07-16
# 2     2025-07-17
# 3     2025-07-18
# 4     2025-07-19
# 5     2025-07-20
# 6     2025-07-21
# 7     2025-07-22
# 8     2025-07-23
# 9     2025-07-24
# 10    2025-07-25
# 11    2025-07-26
# 12    2025-07-27
# 13    2025-07-28
# 14    2025-07-29
# 15    2025-07-30
# 16    2025-07-31
# 17    2025-08-01
# 18    2025-08-02
# 19    2025-08-03
# 20    2025-08-04
# 21    2025-08-05
# 22    2025-08-06
# 23    2025-08-07
# 24    2025-08-08
# 25    2025-08-09
# 26    2025-08-10
# 27    2025-08-11
# 28    2025-08-12
# 29    2025-08-13
# Name: applicableOn, dtype: object

# %% [markdown]
# ### below there is two ways are mentioned for converting json data into pandas data frame, first one is a bit manual but the last one is the better one bcoz its easy to use

# %% [markdown]
# #### Type 1

# %%
import pandas as pd

# Example: if response.json() already gives you this JSON
# For demonstration, let's assume it's stored in 'data'
data = response  # Your JSON from API

# Prepare list to hold flattened rows
rows = []

for entry in data['history']:
    row = {
        "Date": entry['applicableOn'],

        # we have to write the code like bcoz, each dictionary holds multiple nested dictionaries in it
        # Petrol details
        "Petrol Price": entry['fuel']['petrol']['retailPrice'],
        "Petrol Change": entry['fuel']['petrol']['retailPriceChange'],
        "Petrol Unit": entry['fuel']['petrol']['retailUnit'],

        # Diesel details
        "Diesel Price": entry['fuel']['diesel']['retailPrice'],
        "Diesel Change": entry['fuel']['diesel']['retailPriceChange'],
        "Diesel Unit": entry['fuel']['diesel']['retailUnit'],

        # CNG details
        "CNG Price": entry['fuel']['cng']['retailPrice'],
        "CNG Change": entry['fuel']['cng']['retailPriceChange'],
        "CNG Unit": entry['fuel']['cng']['retailUnit'],
        
        # LPG details
        "LPG Price": entry['fuel']['lpg']['retailPrice'],
        "LPG Change": entry['fuel']['lpg']['retailPriceChange'],
        "LPG Unit": entry['fuel']['lpg']['retailUnit'],
    }
    rows.append(row)

# Convert list of rows to DataFrame
df = pd.DataFrame(rows)

# Save to Excel
# df.to_excel("Mumbai_Fuel_Prices.xlsx", index=False)

df
# Out:
#           Date  Petrol Price  Petrol Change Petrol Unit  Diesel Price  \
# 0   2025-07-15        103.49              0       litre         90.01
# 1   2025-07-16        103.49              0       litre         90.01
# 2   2025-07-17        103.49              0       litre         90.01
# 3   2025-07-18        103.49              0       litre         90.01
# 4   2025-07-19        103.49              0       litre         90.01
# 5   2025-07-20        103.49              0       litre         90.01
# 6   2025-07-21        103.49              0       litre         90.01
# 7   2025-07-22        103.49              0       litre         90.01
# 8   2025-07-23        103.49              0       litre         90.01
# 9   2025-07-24        103.49              0       litre         90.01
# 10  2025-07-25        103.49              0       litre         90.01
# 11  2025-07-26        103.49              0       litre         90.01
# 12  2025-07-27        103.49              0       litre         90.01
# 13  2025-07-28        103.49              0       litre         90.01
# 14  2025-07-29        103.49              0       litre         90.01
# 15  2025-07-30        103.49              0       litre         90.01
# 16  2025-07-31        103.49              0       litre         90.01
# 17  2025-08-01        103.49              0       litre         90.01
# 18  2025-08-02        103.49              0       litre         90.01
# 19  2025-08-03        103.49              0       litre         90.01
# 20  2025-08-04        103.49              0       litre         90.01
# 21  2025-08-05        103.49              0       litre         90.01
# 22  2025-08-06        103.49              0       litre         90.01
# 23  2025-08-07        103.49              0       litre         90.01
# 24  2025-08-08        103.49              0       litre         90.01
# 25  2025-08-09        103.49              0       litre         90.01
# 26  2025-08-10        103.49              0       litre         90.01
# 27  2025-08-11        103.49              0       litre         90.01
# 28  2025-08-12        103.49              0       litre         90.01
# 29  2025-08-13        103.49              0       litre         90.01
#
#     Diesel Change Diesel Unit  CNG Price  CNG Change CNG Unit  LPG Price  \
# 0               0       litre         78           2       kg      852.5
# 1               0       litre         78           2       kg      852.5
# 2               0       litre         78           2       kg      852.5
# 3               0       litre         78           2       kg      852.5
# 4               0       litre         78           2       kg      852.5
# 5               0       litre         78           2       kg      852.5
# 6               0       litre         78           2       kg      852.5
# 7               0       litre         78           2       kg      852.5
# 8               0       litre         78           2       kg      852.5
# 9               0       litre         78           2       kg      852.5
# 10              0       litre         78           2       kg      852.5
# 11              0       litre         78           2       kg      852.5
# 12              0       litre         78           2       kg      852.5
# 13              0       litre         78           2       kg      852.5
# 14              0       litre         78           2       kg      852.5
# 15              0       litre         78           2       kg      852.5
# 16              0       litre         78           2       kg      852.5
# 17              0       litre         78           2       kg      852.5
# 18              0       litre         78           2       kg      852.5
# 19              0       litre         78           2       kg      852.5
# 20              0       litre         78           2       kg      852.5
# 21              0       litre         78           2       kg      852.5
# 22              0       litre         78           2       kg      852.5
# 23              0       litre         78           2       kg      852.5
# 24              0       litre         78           2       kg      852.5
# 25              0       litre         78           2       kg      852.5
# 26              0       litre         78           2       kg      852.5
# 27              0       litre         78           2       kg      852.5
# 28              0       litre         78           2       kg      852.5
# 29              0       litre         78           2       kg      852.5
#
#     LPG Change LPG Unit
# 0            0   14.2kg
# 1            0   14.2kg
# 2            0   14.2kg
# 3            0   14.2kg
# 4            0   14.2kg
# 5            0   14.2kg
# 6            0   14.2kg
# 7            0   14.2kg
# 8            0   14.2kg
# 9            0   14.2kg
# 10           0   14.2kg
# 11           0   14.2kg
# 12           0   14.2kg
# 13           0   14.2kg
# 14           0   14.2kg
# 15           0   14.2kg
# 16           0   14.2kg
# 17           0   14.2kg
# 18           0   14.2kg
# 19           0   14.2kg
# 20           0   14.2kg
# 21           0   14.2kg
# 22           0   14.2kg
# 23           0   14.2kg
# 24           0   14.2kg
# 25           0   14.2kg
# 26           0   14.2kg
# 27           0   14.2kg
# 28           0   14.2kg
# 29           0   14.2kg

# %% [markdown]
# #### Type 2

# %%
data = response

df = pd.json_normalize(data['history'], sep='_')

# Add top-level fields manually to every row
top_fields = ['cityId', 'cityName', 'stateId', 'stateName', 'countryId', 'countryName']

for field in top_fields:
    df[field] = data[field]


# Reorder columns to put top-level fields in front
other_cols = [col for col in df.columns if col not in top_fields]
df = df[top_fields + other_cols]



# Optional: rename columns to be more readable
df.rename(columns={
    'applicableOn': 'Date',
    'fuel_petrol_retailPrice': 'Petrol Price',
    'fuel_petrol_retailPriceChange': 'Petrol Change',
    'fuel_petrol_retailUnit': 'Petrol Unit',
    'fuel_diesel_retailPrice': 'Diesel Price',
    'fuel_diesel_retailPriceChange': 'Diesel Change',
    'fuel_diesel_retailUnit': 'Diesel Unit',
    'fuel_cng_retailPrice': 'CNG Price',
    'fuel_cng_retailPriceChange': 'CNG Change',
    'fuel_cng_retailUnit': 'CNG Unit',
    'fuel_lpg_retailPrice': 'LPG Price',
    'fuel_lpg_retailPriceChange': 'LPG Change',
    'fuel_lpg_retailUnit': 'LPG Unit'
}, inplace=True)

# Save to Excel
df.to_excel("Mumbai_Fuel_Prices.xlsx", index=False)

df
# Out:
#     cityId cityName      stateId    stateName countryId countryName  \
# 0   mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 1   mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 2   mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 3   mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 4   mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 5   mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 6   mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 7   mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 8   mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 9   mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 10  mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 11  mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 12  mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 13  mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 14  mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 15  mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 16  mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 17  mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 18  mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 19  mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 20  mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 21  mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 22  mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 23  mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 24  mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 25  mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 26  mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 27  mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 28  mumbai   Mumbai  maharashtra  Maharashtra     india       India
# 29  mumbai   Mumbai  maharashtra  Maharashtra     india       India
#
#           Date  Petrol Price  Petrol Change Petrol Unit  ... CNG Price  \
# 0   2025-07-15        103.49              0       litre  ...        78
# 1   2025-07-16        103.49              0       litre  ...        78
# 2   2025-07-17        103.49              0       litre  ...        78
# 3   2025-07-18        103.49              0       litre  ...        78
# 4   2025-07-19        103.49              0       litre  ...        78
# 5   2025-07-20        103.49              0       litre  ...        78
# 6   2025-07-21        103.49              0       litre  ...        78
# 7   2025-07-22        103.49              0       litre  ...        78
# 8   2025-07-23        103.49              0       litre  ...        78
# 9   2025-07-24        103.49              0       litre  ...        78
# 10  2025-07-25        103.49              0       litre  ...        78
# 11  2025-07-26        103.49              0       litre  ...        78
# 12  2025-07-27        103.49              0       litre  ...        78
# 13  2025-07-28        103.49              0       litre  ...        78
# 14  2025-07-29        103.49              0       litre  ...        78
# 15  2025-07-30        103.49              0       litre  ...        78
# 16  2025-07-31        103.49              0       litre  ...        78
# 17  2025-08-01        103.49              0       litre  ...        78
# 18  2025-08-02        103.49              0       litre  ...        78
# 19  2025-08-03        103.49              0       litre  ...        78
# 20  2025-08-04        103.49              0       litre  ...        78
# 21  2025-08-05        103.49              0       litre  ...        78
# 22  2025-08-06        103.49              0       litre  ...        78
# 23  2025-08-07        103.49              0       litre  ...        78
# 24  2025-08-08        103.49              0       litre  ...        78
# 25  2025-08-09        103.49              0       litre  ...        78
# 26  2025-08-10        103.49              0       litre  ...        78
# 27  2025-08-11        103.49              0       litre  ...        78
# 28  2025-08-12        103.49              0       litre  ...        78
# 29  2025-08-13        103.49              0       litre  ...        78
#
#    CNG Change  CNG Unit  fuel_cng_currency fuel_cng_retailPriceChangeInterval  \
# 0           2        kg                INR                              month
# 1           2        kg                INR                              month
# 2           2        kg                INR                              month
# 3           2        kg                INR                              month
# 4           2        kg                INR                              month
# 5           2        kg                INR                              month
# 6           2        kg                INR                              month
# 7           2        kg                INR                              month
# 8           2        kg                INR                              month
# 9           2        kg                INR                              month
# 10          2        kg                INR                              month
# 11          2        kg                INR                              month
# 12          2        kg                INR                              month
# 13          2        kg                INR                              month
# 14          2        kg                INR                              month
# 15          2        kg                INR                              month
# 16          2        kg                INR                              month
# 17          2        kg                INR                              month
# 18          2        kg                INR                              month
# 19          2        kg                INR                              month
# 20          2        kg                INR                              month
# 21          2        kg                INR                              month
# 22          2        kg                INR                              month
# 23          2        kg                INR                              month
# 24          2        kg                INR                              month
# 25          2        kg                INR                              month
# 26          2        kg                INR                              month
# 27          2        kg                INR                              month
# 28          2        kg                INR                              month
# 29          2        kg                INR                              month
#
#    LPG Price LPG Change  LPG Unit  fuel_lpg_currency  \
# 0      852.5          0    14.2kg                INR
# 1      852.5          0    14.2kg                INR
# 2      852.5          0    14.2kg                INR
# 3      852.5          0    14.2kg                INR
# 4      852.5          0    14.2kg                INR
# 5      852.5          0    14.2kg                INR
# 6      852.5          0    14.2kg                INR
# 7      852.5          0    14.2kg                INR
# 8      852.5          0    14.2kg                INR
# 9      852.5          0    14.2kg                INR
# 10     852.5          0    14.2kg                INR
# 11     852.5          0    14.2kg                INR
# 12     852.5          0    14.2kg                INR
# 13     852.5          0    14.2kg                INR
# 14     852.5          0    14.2kg                INR
# 15     852.5          0    14.2kg                INR
# 16     852.5          0    14.2kg                INR
# 17     852.5          0    14.2kg                INR
# 18     852.5          0    14.2kg                INR
# 19     852.5          0    14.2kg                INR
# 20     852.5          0    14.2kg                INR
# 21     852.5          0    14.2kg                INR
# 22     852.5          0    14.2kg                INR
# 23     852.5          0    14.2kg                INR
# 24     852.5          0    14.2kg                INR
# 25     852.5          0    14.2kg                INR
# 26     852.5          0    14.2kg                INR
# 27     852.5          0    14.2kg                INR
# 28     852.5          0    14.2kg                INR
# 29     852.5          0    14.2kg                INR
#
#    fuel_lpg_retailPriceChangeInterval
# 0                               month
# 1                               month
# 2                               month
# 3                               month
# 4                               month
# 5                               month
# 6                               month
# 7                               month
# 8                               month
# 9                               month
# 10                              month
# 11                              month
# 12                              month
# 13                              month
# 14                              month
# 15                              month
# 16                              month
# 17                              month
# 18                              month
# 19                              month
# 20                              month
# 21                              month
# 22                              month
# 23                              month
# 24                              month
# 25                              month
# 26                              month
# 27                              month
# 28                              month
# 29                              month
#
# [30 rows x 27 columns]

# %% [markdown]
# When converting data to a pandas DataFrame, the data does NOT need to be only a dictionary—pandas supports several input formats:
#
# ![alt text](image.png) ![image.png](attachment:image.png)
#
#
#
# ### What will NOT work directly:
# A list of single values (without columns):
# data = [1][2][3] gives you a single-column DataFrame, unless you give column names.
#
# A completely nested or weird structure—pandas expects, at minimum, something "tabular": lists/arrays/dicts that map to rows and columns.
