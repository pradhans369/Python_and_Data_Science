# %% [markdown]
# # **Gini Impurity**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Since table 2 has less gini impurity than the table 1, hence table 2 is giving more info than the table 1.
#
# Gini Impurity is a metric used by the CART (Classification and Regression Trees) algorithm to determine the best way to split a dataset. It measures the probability that a randomly chosen element from a set would be incorrectly labeled if it was randomly labeled according to the distribution of labels in the subset.

# %% [markdown]
# Entropy is slower coz we use logs, but Gini is faster.
#
# But in certain cases Entropy will give you more accurate resualts compared to Gini, While using Gini might lead to overfitting.

# %% [markdown]
# ---
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
