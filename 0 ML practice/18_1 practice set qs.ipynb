# %% [markdown]
# ### The "City Revenue" (GroupBy)
# **Scenario:** You have a dataframe containing thousands of sales records. You want to know exactly how much money was made in each specific city.
#
# **Your Task:** Write a function `get_city_revenue(df, city_col, revenue_col)` that returns a new Pandas Series showing the **total sum** of revenue for each city.
#
# > *(Hint: Look into the `df.groupby()` function combined with `.sum()`)*

# %%
def get_city_reveneu(df, city_col, revenue_col):

# %% [markdown]
# ---

# %% [markdown]
# ### The "Data Cleaner" (Handling Missing Values)
# **Scenario:** You scraped some data, but there are blank cells (`NaN` / Not a Number) in the `Age` column because some users didn't enter their birthday. Machine Learning models will crash if they see `NaN` values.
#
# **Your Task:** Write a function `fill_missing_ages(df, age_col)` that permanently modifies the dataframe by replacing any missing values in the `age_col` with the **average (mean)** age of the entire column.
#
# > *(Hint: Pandas has a built in function called `.fillna()` and `.mean()`. You can chain them together!)*

# %% [markdown]
# ---

# %% [markdown]
# ### The "Discount Creator" (Derived Columns)
# **Scenario:** Your store is running a 20% off sale. You have a dataframe with a `price` column, but you need a brand new column that shows the final sale price after the discount.
#
# **Your Task:** Write a function `apply_discount(df, price_col)` that creates a brand new column in your dataframe named `'Sale_Price'`. The values in this new column should be the original price multiplied by `0.80`.
#
# > *(Hint: In Pandas, creating a new column and doing math on an entire column does not require a `for` loop. You can just declare `df['New_Column_Name'] = ...`)*
